# %% [markdown]
# <a href="https://colab.research.google.com/github/fedor44/subplot_test/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 한글 관련 설정
plt.rc('font', family='NanumGothic')
plt.rc('axes', unicode_minus=False)

# 기본 값 세팅
사모예드 = pd.DataFrame({"길이":[75, 77, 86, 79, 83, 86, 88, 83],
                         "높이":[56, 57, 53, 60, 49, 50, 61, 53]
                        })

푸들 = pd.DataFrame({"길이":[34, 38, 41, 30, 38, 37, 35, 41],
                     "높이":[22, 19, 30, 21, 25, 24, 18, 28]
                    })

# 각 plot 값 세팅
ax1 = plt.subplot(2, 1, 1)
x1 = 사모예드["길이"]
y1 = 사모예드["높이"]
plt.title("사모예드 사이즈")
plt.plot(x1, y1, c = "r", marker = "s")
plt.xlabel("길이")
plt.ylabel("높이")

ax1 = plt.subplot(2, 1, 2)
x2 = 푸들["길이"]
y2 = 푸들["높이"]
plt.title("푸들 사이즈")
plt.plot(x2, y2, c = "b", marker = "^")
plt.xlabel("길이")
plt.ylabel("높이")

# subplot 간격 조절
plt.tight_layout()

# 결과 출력
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
